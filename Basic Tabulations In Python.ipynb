# %%
import pandas as pd
Cancer_Data = pd.read_csv(r"C:\Users\HP\Downloads\Cancer Data.csv")
Cancer_Data
# Out:
#     patient_id  age  gender        bmi  smoking  exercise  fruit  veg  cancer
# 0            1   61       0  20.797214      2.0         0      1    2       0
# 1            2   68       1  27.300000      0.0         0      0    1       0
# 2            3   62       1  22.183096      0.0         0      1    3       0
# 3            4   61       1  35.268460      2.0         0      2    4       0
# 4            5   58       1  22.673343      1.0         0      3    1       0
# ..         ...  ...     ...        ...      ...       ...    ...  ...     ...
# 61          62   60       0  25.091993      2.0         2      0    3       0
# 62          63   70       0  21.933289      0.0         2      0    0       0
# 63          64   68       1  27.300000      0.0         2      1    9       0
# 64          65   69       1  27.365738      2.0         2      2    9       0
# 65          66   46       0  25.945921      NaN         2      1    9       0
#
# [66 rows x 9 columns]

# %%
print(Cancer_Data.to_string()) #to_string prints the entire table
# Out:
#     patient_id  age  gender        bmi  smoking  exercise  fruit  veg  cancer
# 0            1   61       0  20.797214      2.0         0      1    2       0
# 1            2   68       1  27.300000      0.0         0      0    1       0
# 2            3   62       1  22.183096      0.0         0      1    3       0
# 3            4   61       1  35.268460      2.0         0      2    4       0
# 4            5   58       1  22.673343      1.0         0      3    1       0
# 5            6   46       1  27.690345      1.0         0      0    2       1
# 6            7   67       1  28.957309      2.0         0      0    3       1
# 7            8   68       0  19.833992      0.0         0      3    4       0
# 8            9   53       1  17.551419      0.0         0      1    3       0
# 9           10   59       0  27.722870      2.0         0      1    3       0
# 10          11   72       0  22.710643      1.0         0      1    2       0
# ...

# %%
Cancer_Data["bmi"] # to select a column
# Out:
# 0     20.797214
# 1     27.300000
# 2     22.183096
# 3     35.268460
# 4     22.673343
#         ...
# 61    25.091993
# 62    21.933289
# 63    27.300000
# 64    27.365738
# 65    25.945921
# Name: bmi, Length: 66, dtype: float64

# %%
Cancer_Data[["age", "bmi", "gender"]] # to select more than one column, note the square bracket is more than one in this case
# Out:
#     age        bmi  gender
# 0    61  20.797214       0
# 1    68  27.300000       1
# 2    62  22.183096       1
# 3    61  35.268460       1
# 4    58  22.673343       1
# ..  ...        ...     ...
# 61   60  25.091993       0
# 62   70  21.933289       0
# 63   68  27.300000       1
# 64   69  27.365738       1
# 65   46  25.945921       0
#
# [66 rows x 3 columns]

# %% [markdown]
# ----

# %% [markdown]
# ## loc and iloc

# %% [markdown]
# **loc** selects rows and columns with specific ***labels***.
#
# but our data does not have labels, so the label will be their default index positions

# %%
# select rows with certain labels ( note the index will be the labels as the data is not labelled)
Cancer_Data.loc[[1,2,35]] # select rows with index 1, 2 and 35
# Out:
#     patient_id  age  gender        bmi  smoking  exercise  fruit  veg  cancer
# 1            2   68       1  27.300000      0.0         0      0    1       0
# 2            3   62       1  22.183096      0.0         0      1    3       0
# 35          36   73       0  27.219021      2.0         1      1    2       0

# %%
# select rows and columns with certain labels
Cancer_Data.loc[[1,2,35,], ["age", "gender", "bmi"]] # note the label for a column is the name of the column
# Out:
#     age  gender        bmi
# 1    68       1  27.300000
# 2    62       1  22.183096
# 35   73       0  27.219021

# %%
# we can select a range using :
Cancer_Data.loc[5:10, :"bmi"] # rows index no. 1 to 10 of the first column to column "bmi"
# Out:
#     patient_id  age  gender        bmi
# 5            6   46       1  27.690345
# 6            7   67       1  28.957309
# 7            8   68       0  19.833992
# 8            9   53       1  17.551419
# 9           10   59       0  27.722870
# 10          11   72       0  22.710643

# %%
Cancer_Data.loc[5, "bmi"] # to select the fifth row of the column
# Out:
# 27.6903451128586

# %% [markdown]
# **iloc** selects rows and columns at specific ***integer position***

# %%
# select rows 4 and 5 bases on their index (not labels, iloc doesn't use labels)
Cancer_Data.iloc[4:6] # note it will exclude 6
# Out:
#    patient_id  age  gender        bmi  smoking  exercise  fruit  veg  cancer
# 4           5   58       1  22.673343      1.0         0      3    1       0
# 5           6   46       1  27.690345      1.0         0      0    2       1

# %%
Cancer_Data.iloc[4:6, :4] # select rows 4 to 5(will exclude 6) and the first column to the 3rd(will exclude 4)
# Out:
#    patient_id  age  gender        bmi
# 4           5   58       1  22.673343
# 5           6   46       1  27.690345

# %%
Cancer_Data.iloc[:5, [1,2,3]] # first five rows in column, 1,2,3
# Out:
#    age  gender        bmi
# 0   61       0  20.797214
# 1   68       1  27.300000
# 2   62       1  22.183096
# 3   61       1  35.268460
# 4   58       1  22.673343

# %% [markdown]
# ###### note if we are selcecting multiple rows or columns without using range, we include square bracket
